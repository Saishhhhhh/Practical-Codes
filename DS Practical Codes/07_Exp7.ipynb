# %% [markdown]
# Title: Text Analytics

# %% [markdown]
# PROBLEM STATEMENT:
# 1. Extract Sample document and apply following document preprocessing methods: Tokenization, POS
# Tagging, stop words removal, Stemming and Lemmatization.
# 2. Create representation of documents by calculating Term Frequency and Inverse Document Frequency.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bsais\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bsais\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\bsais\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\bsais\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
text = """Text analytics is the process of analyzing textual data. 
It involves tokenization, stop word removal, stemming and lemmatization. 
Machine learning models use this processed data for better predictions."""

# %%
sent_tokens = sent_tokenize(text)
word_tokens = word_tokenize(text)

print("Sentence Tokens:", sent_tokens)
print("Word Tokens:", word_tokens)
# Out:
# Sentence Tokens: ['Text analytics is the process of analyzing textual data.', 'It involves tokenization, stop word removal, stemming and lemmatization.', 'Machine learning models use this processed data for better predictions.']
# Word Tokens: ['Text', 'analytics', 'is', 'the', 'process', 'of', 'analyzing', 'textual', 'data', '.', 'It', 'involves', 'tokenization', ',', 'stop', 'word', 'removal', ',', 'stemming', 'and', 'lemmatization', '.', 'Machine', 'learning', 'models', 'use', 'this', 'processed', 'data', 'for', 'better', 'predictions', '.']

# %%
stop_words = set(stopwords.words('english'))

filtered_words = [w for w in word_tokens if w.lower() not in stop_words]

print("After Stopword Removal:", filtered_words)
# Out:
# After Stopword Removal: ['Text', 'analytics', 'process', 'analyzing', 'textual', 'data', '.', 'involves', 'tokenization', ',', 'stop', 'word', 'removal', ',', 'stemming', 'lemmatization', '.', 'Machine', 'learning', 'models', 'use', 'processed', 'data', 'better', 'predictions', '.']

# %%
pos_tags = pos_tag(filtered_words)

print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('analyzing', 'VBG'), ('textual', 'JJ'), ('data', 'NNS'), ('.', '.'), ('involves', 'VBZ'), ('tokenization', 'NN'), (',', ','), ('stop', 'VB'), ('word', 'NN'), ('removal', 'NN'), (',', ','), ('stemming', 'VBG'), ('lemmatization', 'NN'), ('.', '.'), ('Machine', 'NNP'), ('learning', 'VBG'), ('models', 'NNS'), ('use', 'VBP'), ('processed', 'VBN'), ('data', 'NNS'), ('better', 'RBR'), ('predictions', 'NNS'), ('.', '.')]

# %%
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(w) for w in filtered_words]

print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['text', 'analyt', 'process', 'analyz', 'textual', 'data', '.', 'involv', 'token', ',', 'stop', 'word', 'remov', ',', 'stem', 'lemmat', '.', 'machin', 'learn', 'model', 'use', 'process', 'data', 'better', 'predict', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]

print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['Text', 'analytics', 'process', 'analyzing', 'textual', 'data', '.', 'involves', 'tokenization', ',', 'stop', 'word', 'removal', ',', 'stemming', 'lemmatization', '.', 'Machine', 'learning', 'model', 'use', 'processed', 'data', 'better', 'prediction', '.']

# %%
documents = [text]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print("Feature Names:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n", tfidf_matrix.toarray())
# Out:
# Feature Names: ['analytics' 'analyzing' 'and' 'better' 'data' 'for' 'involves' 'is' 'it'
#  'learning' 'lemmatization' 'machine' 'models' 'of' 'predictions'
#  'process' 'processed' 'removal' 'stemming' 'stop' 'text' 'textual' 'the'
#  'this' 'tokenization' 'use' 'word']
# TF-IDF Matrix:
#  [[0.18257419 0.18257419 0.18257419 0.18257419 0.36514837 0.18257419
#   0.18257419 0.18257419 0.18257419 0.18257419 0.18257419 0.18257419
#   0.18257419 0.18257419 0.18257419 0.18257419 0.18257419 0.18257419
#   0.18257419 0.18257419 0.18257419 0.18257419 0.18257419 0.18257419
#   0.18257419 0.18257419 0.18257419]]
